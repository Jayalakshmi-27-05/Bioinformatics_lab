# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayalakshmi-27-05/Bioinformatics_lab/blob/main/7_genome_assembly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install fastqc
# !apt-get install velvet
# !wget 'https://zenodo.org/record/582600/files/mutant_R1.fastq'
# !wget 'https://zenodo.org/record/582600/files/mutant_R2.fastq'
import os
from google.colab import files
get_ipython().system("fastqc mutant_R1.fastq")
files.download('mutant_R1_fastqc.html')
get_ipython().system("fastqc mutant_R2.fastq")
files.download('mutant_R2_fastqc.html')
# !mkdir assembly_module
os.chdir('assembly_module')
# !mkdir data
get_ipython().system("velveth ASM_NAME 31 -short -separate -fastq /content/mutant_R1.fastq /content/mutant_R2.fastq")
get_ipython().system("velvetg ASM_NAME")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fastqc is already the newest version (0.11.9+dfsg-5).
# 0 upgraded, 0 newly installed, 0 to remove and 67 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# velvet is already the newest version (1.2.10+dfsg1-7).
# 0 upgraded, 0 newly installed, 0 to remove and 67 not upgraded.
# --2025-12-09 04:39:14--  https://zenodo.org/record/582600/files/mutant_R1.fastq
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.185.48.75, 137.138.52.235, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/582600/files/mutant_R1.fastq [following]
# --2025-12-09 04:39:14--  https://zenodo.org/records/582600/files/mutant_R1.fastq
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4137809 (3.9M) [application/octet-stream]
# Saving to: ‘mutant_R1.fastq.3’
#
# mutant_R1.fastq.3   100%[===================>]   3.95M   902KB/s    in 4.5s
#
# 2025-12-09 04:39:19 (902 KB/s) - ‘mutant_R1.fastq.3’ saved [4137809/4137809]
#
# --2025-12-09 04:39:19--  https://zenodo.org/record/582600/files/mutant_R2.fastq
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.185.48.75, 137.138.52.235, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/582600/files/mutant_R2.fastq [following]
# --2025-12-09 04:39:20--  https://zenodo.org/records/582600/files/mutant_R2.fastq
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4137809 (3.9M) [application/octet-stream]
# Saving to: ‘mutant_R2.fastq.3’
#
# mutant_R2.fastq.3   100%[===================>]   3.95M   819KB/s    in 4.9s
#
# 2025-12-09 04:39:25 (819 KB/s) - ‘mutant_R2.fastq.3’ saved [4137809/4137809]
#
# Started analysis of mutant_R1.fastq
# Approx 5% complete for mutant_R1.fastq
# Approx 15% complete for mutant_R1.fastq
# Approx 20% complete for mutant_R1.fastq
# Approx 30% complete for mutant_R1.fastq
# Approx 40% complete for mutant_R1.fastq
# Approx 45% complete for mutant_R1.fastq
# Approx 55% complete for mutant_R1.fastq
# Approx 60% complete for mutant_R1.fastq
# Approx 70% complete for mutant_R1.fastq
# Approx 80% complete for mutant_R1.fastq
# Approx 85% complete for mutant_R1.fastq
# Approx 95% complete for mutant_R1.fastq
# Analysis complete for mutant_R1.fastq
# Started analysis of mutant_R2.fastq
# Approx 5% complete for mutant_R2.fastq
# Approx 15% complete for mutant_R2.fastq
# Approx 20% complete for mutant_R2.fastq
# Approx 30% complete for mutant_R2.fastq
# Approx 40% complete for mutant_R2.fastq
# Approx 45% complete for mutant_R2.fastq
# Approx 55% complete for mutant_R2.fastq
# Approx 60% complete for mutant_R2.fastq
# Approx 70% complete for mutant_R2.fastq
# Approx 80% complete for mutant_R2.fastq
# Approx 85% complete for mutant_R2.fastq
# Approx 95% complete for mutant_R2.fastq
# Analysis complete for mutant_R2.fastq
# mkdir: cannot create directory ‘assembly_module’: File exists
# [0.000000] Reading FastQ file /content/mutant_R1.fastq;
# [0.053976] 12480 sequences found
# [0.054000] Done
# [0.054053] Reading FastQ file /content/mutant_R2.fastq;
# [0.115376] 12480 sequences found
# [0.115395] Done
# [0.115464] Reading read set file ASM_NAME/Sequences;
# [0.122075] 24960 sequences found
# [0.153862] Done
# [0.153887] 24960 sequences in total.
# [0.154009] Writing into roadmap file ASM_NAME/Roadmaps...
# [0.205618] Inputting sequences...
# [0.205650] Inputting sequence 0 / 24960
# [1.104092]  === Sequences loaded in 0.898477 s
# [1.104135] Done inputting sequences
# [1.104138] Destroying splay table
# [1.115521] Splay table destroyed
# [0.000000] Reading roadmap file ASM_NAME/Roadmaps
# [0.049871] 24960 roadmaps read
# [0.050148] Creating insertion markers
# [0.053743] Ordering insertion markers
# [0.073245] Counting preNodes
# [0.076988] 64223 preNodes counted, creating them now
# [0.177720] Adjusting marker info...
# [0.181471] Connecting preNodes
# [0.220379] Cleaning up memory
# [0.220517] Done creating preGraph
# [0.220526] Concatenation...
# [0.241792] Renumbering preNodes
# [0.241825] Initial preNode count 64223
# [0.244172] Destroyed 37924 preNodes
# [0.244206] Concatenation over!
# [0.244210] Clipping short tips off preGraph
# [0.245889] Concatenation...
# [0.250954] Renumbering preNodes
# [0.250984] Initial preNode count 26299
# [0.252678] Destroyed 3832 preNodes
# [0.252696] Concatenation over!
# [0.252698] 1986 tips cut off
# [0.252700] 22467 nodes left
# [0.252797] Writing into pregraph file ASM_NAME/PreGraph...
# [0.326694] Reading read set file ASM_NAME/Sequences;
# [0.331539] 24960 sequences found
# [0.354823] Done
# [0.407328] Reading pre-graph file ASM_NAME/PreGraph
# [0.407469] Graph has 22467 nodes and 24960 sequences
# [0.435362] Scanning pre-graph file ASM_NAME/PreGraph for k-mers
# [0.440899] 434645 kmers found
# [0.473903] Sorting kmer occurrence table ...
# [0.608406] Sorting done.
# [0.608434] Computing acceleration table...
# [0.666148] Computing offsets...
# [0.669506] Ghost Threading through reads 0 / 24960
# [0.669845]  === Ghost-Threaded in 0.000340 s
# [0.669859] Threading through reads 0 / 24960
# [2.138576]  === Threaded in 1.468717 s
# [2.144536] Correcting graph with cutoff 0.200000
# [2.147322] Determining eligible starting points
# [2.176208] Done listing starting nodes
# [2.176242] Initializing todo lists
# [2.183238] Done with initialization
# [2.183279] Activating arc lookup table
# [2.187033] Done activating arc lookup table
# [2.311665] 10000 / 22467 nodes visited
# [2.485422] 20000 / 22467 nodes visited
# [2.528258] Concatenation...
# [2.528543] Renumbering nodes
# [2.528558] Initial node count 22467
# [2.528734] Removed 22097 null nodes
# [2.528746] Concatenation over!
# [2.528767] Clipping short tips off graph, drastic
# [2.528812] Concatenation...
# [2.529086] Renumbering nodes
# [2.529098] Initial node count 370
# [2.529112] Removed 14 null nodes
# [2.529120] Concatenation over!
# [2.529127] 356 nodes left
# [2.529303] Writing into graph file ASM_NAME/Graph...
# [2.563318] WARNING: NO COVERAGE CUTOFF PROVIDED
# [2.563349] Velvet will probably leave behind many detectable errors
# [2.563351] See manual for instructions on how to set the coverage cutoff parameter
# [2.563355] Removing contigs with coverage < -1.000000...
# [2.563391] Concatenation...
# [2.563417] Renumbering nodes
# [2.563423] Initial node count 356
# [2.563430] Removed 0 null nodes
# [2.563436] Concatenation over!
# [2.563452] Concatenation...
# [2.563470] Renumbering nodes
# [2.563476] Initial node count 356
# [2.563482] Removed 0 null nodes
# [2.563488] Concatenation over!
# [2.563494] Clipping short tips off graph, drastic
# [2.563507] Concatenation...
# [2.563525] Renumbering nodes
# [2.563531] Initial node count 356
# [2.563534] Removed 0 null nodes
# [2.563540] Concatenation over!
# [2.563546] 356 nodes left
# [2.563552] WARNING: NO EXPECTED COVERAGE PROVIDED
# [2.563557] Velvet will be unable to resolve any repeats
# [2.563563] See manual for instructions on how to set the expected coverage parameter
# [2.563569] Concatenation...
# [2.563587] Renumbering nodes
# [2.563593] Initial node count 356
# [2.563599] Removed 0 null nodes
# [2.563605] Concatenation over!
# [2.563610] Removing reference contigs with coverage < -1.000000...
# [2.563634] Concatenation...
# [2.563653] Renumbering nodes
# [2.563658] Initial node count 356
# [2.563664] Removed 0 null nodes
# [2.563669] Concatenation over!
# [2.563939] Writing contigs into ASM_NAME/contigs.fa...
# [2.590429] Writing into stats file ASM_NAME/stats.txt...
# [2.592279] Writing into graph file ASM_NAME/LastGraph...
# Final graph has 356 nodes and n50 of 5029, max 12902, total 184065, using 0/24960 reads
